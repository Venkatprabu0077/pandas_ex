# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkatprabu0077/pandas_ex/blob/main/pandas_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([10,12,13,44,56])
type(s)
# Out:
# pandas.core.series.Series

# %%
a=np.array([10,12,13,44,56])

# %%
s
# Out:
# 0    10
# 1    12
# 2    13
# 3    44
# 4    56
# dtype: int64

# %%
s.iloc[1]
# Out:
# 12

# %%
ss=pd.Series([10,12,13,44,56],index=['a','b','c','a','e'])
ss
# Out:
# a    10
# b    12
# c    13
# a    44
# e    56
# dtype: int64

# %%
ss['a']
# Out:
# a    10
# a    44
# dtype: int64

# %%
ss.iloc[3]
# Out:
# 44

# %%
data=[['alex',10,'23-05-2000'],['bob',None,None],['clark',None,'23.05.200']]

# %%
data
# Out:
# [['alex', 10, '23-05-2000'], ['bob', None, None], ['clark', None, '23.05.200']]

# %%
df=pd.DataFrame(data)
df
# Out:
#        0     1           2
# 0   alex  10.0  23-05-2000
# 1    bob   NaN        None
# 2  clark   NaN   23.05.200

# %%
df[0][0]
# Out:
# 'alex'

# %%
df[0:2]
# Out:
#       0     1           2
# 0  alex  10.0  23-05-2000
# 1   bob   NaN        None

# %%
df[[0,2]]
# Out:
#        0           2
# 0   alex  23-05-2000
# 1    bob        None
# 2  clark   23.05.200

# %%
df=pd.DataFrame(data,columns=['firstname','age','DOB'])
df['firstname']
# Out:
# 0     alex
# 1      bob
# 2    clark
# Name: firstname, dtype: object

# %%
df.iloc[0:1]
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000

# %%
s.plot()
# Out:
# <Axes: >

# %%
ss.plot()
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# firstname    0
# age          2
# DOB          1
# dtype: int64

# %%
data=[['alex',10,'23-05-2000'],['bob',None,None],['clark',None,'23.05.2001']]
df=pd.DataFrame(data,columns=['firstname','age','DOB'])
df
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000
# 1       bob   NaN        None
# 2     clark   NaN  23.05.2001

# %%
df.drop([1])
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000
# 2     clark   NaN  23.05.2001

# %%
a
# Out:
# array([10, 12, 13, 44, 56])

# %%
a[a>20]
# Out:
# array([44, 56])

# %%
a[a%2==0]
# Out:
# array([10, 12, 44, 56])

# %%
df=pd.read_table('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv')

# %%
df.dropna()
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %%
df.item_price=df.item_price.str.replace('$','')
# Out:
# <ipython-input-213-20961e8be3c3>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')

# %%
df.dropna()
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]      3.39
# 2                                               [Apple]      3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...     10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...     11.75
# ...

# %% [markdown]
# df['item_price']=df['item_price'].apply(lambda x:float(x)*100)
# df

# %%
df=df.dropna()

# %%
df
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]      3.39
# 2                                               [Apple]      3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...     10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...     11.75
# ...

# %%
df['item_price']=df['item_price'].apply(lambda x:float(x))
df_drink =df[df.item_price<1.1]
df_drink
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 28          14         1  Canned Soda       [Dr. Pepper]        1.09
# 53          24         1  Canned Soda           [Sprite]        1.09
# 107         47         1  Canned Soda       [Dr. Pepper]        1.09
# 117         51         1  Canned Soda  [Diet Dr. Pepper]        1.09
# 126         55         1  Canned Soda        [Coca Cola]        1.09
# ...        ...       ...          ...                ...         ...
# 3897      1562         1  Canned Soda     [Mountain Dew]        1.09
# 3926      1575         1  Canned Soda       [Dr. Pepper]        1.09
# 3936      1578         1  Canned Soda  [Diet Dr. Pepper]        1.09
# 4008      1604         1  Canned Soda        [Diet Coke]        1.09
# 4051      1621         1  Canned Soda           [Sprite]        1.09
#
# [84 rows x 5 columns]

# %%
df_drink.item_name.nunique()
# Out:
# 1

# %%
label_counts = df['item_name'].value_counts()
label_counts
# Out:
# Chicken Bowl             726
# Chicken Burrito          553
# Steak Burrito            368
# Canned Soft Drink        301
# Steak Bowl               211
# Chicken Soft Tacos       115
# Chicken Salad Bowl       110
# Canned Soda              104
# Veggie Burrito            95
# Barbacoa Burrito          91
# Veggie Bowl               85
# Carnitas Bowl             68
# Barbacoa Bowl             66
# Carnitas Burrito          59
# Steak Soft Tacos          55
# 6 Pack Soft Drink         54
# Chicken Crispy Tacos      47
# Carnitas Soft Tacos       40
# Steak Crispy Tacos        35
# Steak Salad Bowl          29
# Nantucket Nectar          27
# Barbacoa Soft Tacos       25
# Izze                      20
# Veggie Salad Bowl         18
# Barbacoa Crispy Tacos     11
# Barbacoa Salad Bowl       10
# Chicken Salad              9
# Carnitas Crispy Tacos      7
# Veggie Soft Tacos          7
# Burrito                    6
# Carnitas Salad Bowl        6
# Veggie Salad               6
# ...

# %%
filtered=df[df['item_name'] == 'Chicken Salad']
filtered
# Out:
#       order_id  quantity      item_name  \
# 250        109         1  Chicken Salad
# 1065       439         1  Chicken Salad
# 2968      1181         1  Chicken Salad
# 3045      1212         1  Chicken Salad
# 3363      1349         1  Chicken Salad
# 3730      1490         1  Chicken Salad
# 3733      1491         1  Chicken Salad
# 3982      1596         1  Chicken Salad
# 3989      1598         1  Chicken Salad
#
#                                      choice_description  item_price
# 250   [Roasted Chili Corn Salsa (Medium), [Black Bea...       10.98
# 1065  [[Tomatillo-Green Chili Salsa (Medium), Roaste...       10.98
# 2968           [Fresh Tomato Salsa (Mild), Black Beans]        8.49
# 3045           [Fresh Tomato Salsa (Mild), Black Beans]        8.49
# 3363  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...        8.49
# 3730           [Fresh Tomato Salsa (Mild), Black Beans]        8.49
# 3733  [Fresh Tomato Salsa (Mild), [Black Beans, Chee...        8.49
# ...

# %%
df[df.item_name=='Chicken Salad'].choice_description.nunique()
# Out:
# 7

# %%
df['choice_description']
# Out:
# 1                                            [Clementine]
# 2                                                 [Apple]
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5       [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 7       [Tomatillo Red Chili Salsa, [Fajita Vegetables...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 3376, dtype: object

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price<10) & (df.item_name=='Chicken Bowl')].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
df=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.dropna(inplace=True)

# %%
df[(df.	star_rating>8) & (df.content_rating=='R')].sort_values(['duration'],ascending=False)
# Out:
#      star_rating                        title content_rating      genre  \
# 78           8.4  Once Upon a Time in America              R      Crime
# 2            9.1       The Godfather: Part II              R      Crime
# 8            8.9             Schindler's List              R  Biography
# 40           8.5               The Green Mile              R      Crime
# 184          8.2          Fanny and Alexander              R      Drama
# ..           ...                          ...            ...        ...
# 190          8.2                Life of Brian              R     Comedy
# 172          8.2                Trainspotting              R      Drama
# 206          8.1                  Stand by Me              R  Adventure
# 225          8.1                       3-Iron              R      Crime
# 283          8.1                Before Sunset              R      Drama
#
#      duration                                        actors_list
# ...

# %%
df[df.actors_list.str.contains('Christian Bale')]
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 3            9.0        The Dark Knight          PG-13     Action       152
# 43           8.5  The Dark Knight Rises          PG-13     Action       165
# 53           8.5           The Prestige          PG-13      Drama       130
# 113          8.3          Batman Begins          PG-13     Action       140
# 446          7.9            The Fighter              R  Biography       116
# 504          7.8      Empire of the Sun             PG      Drama       153
# 555          7.8           3:10 to Yuma              R  Adventure       122
# 589          7.7          The Machinist              R      Drama       101
# 702          7.6  Jin ling shi san chai              R      Drama       146
# 732          7.6        American Psycho              R      Crime       102
# 815          7.6            Equilibrium              R     Action       107
#
#                                            actors_list
# ...

# %%
df=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv')
df.isnull()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 0      False             True           False  False  False
# 1      False             True           False  False  False
# 2      False             True           False  False  False
# 3      False             True           False  False  False
# 4      False             True           False  False  False
# ...      ...              ...             ...    ...    ...
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False
#
# [18241 rows x 5 columns]

# %%
df.dropna(inplace=True)

# %%
drinks=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks['total_litres_of_pure_alcohol'].mean()
# Out:
# 4.717098445595855

# %%
drinks[drinks.continent=='Asia']
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
drinks[drinks.continent=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.agg(['min','max','mean'])
# Out:
#                min  max        mean
# continent
# Africa           0  376   61.471698
# Asia             0  247   37.045455
# Europe           0  361  193.777778
# North America    1  285  145.434783
# Oceania          0  306   89.687500
# South America   93  333  175.083333
